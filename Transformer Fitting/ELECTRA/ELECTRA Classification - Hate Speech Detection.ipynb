# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, matthews_corrcoef
import torch
from transformers import TrainingArguments, Trainer
from transformers import ElectraTokenizer, ElectraForSequenceClassification
from transformers import EarlyStoppingCallback

# %% [markdown]
# ### Load Data Set

# %%
df_train = pd.read_csv('training.csv')
df_val = pd.read_csv('validation.csv')
df_test = pd.read_csv('testing.csv')

df_train.head()
# Out:
#    Unnamed: 0                                               text  label
# 0       19429  retweet mentionhere: people be like from bae t...      1
# 1       10662  i like being teased, do not give me the pussy ...      1
# 2       19558         retweet mentionhere: you are jealous bitch      1
# 3        2909  mentionhere cuz people at work are bitches the...      1
# 4       24378  quote this with your best racist comment i nee...      1

# %%
# Define pretrained tokenizer and model

model_name = 'google/electra-small-discriminator'

tokenizer = ElectraTokenizer.from_pretrained(model_name)

model = ElectraForSequenceClassification.from_pretrained(model_name, num_labels=3)
# Out:
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/54.2M [00:00<?, ?B/s]
# Some weights of the model checkpoint at google/electra-small-discriminator were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.weight', 'discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense.bias']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at google/electra-small-discriminator and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# ----- 1. Preprocess data -----#
# Preprocess data

X_train = list(df_train["text"])
y_train = list(df_train["label"])

X_val = list(df_val["text"])
y_val = list(df_val["label"])

X_train_tokenized = tokenizer(X_train, padding=True, truncation=True, max_length=512)
X_val_tokenized = tokenizer(X_val, padding=True, truncation=True, max_length=512)

# %%
# Create torch dataset
class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels=None):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        if self.labels:
            item["labels"] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.encodings["input_ids"])

# %%
train_dataset = Dataset(X_train_tokenized, y_train)
val_dataset = Dataset(X_val_tokenized, y_val)

# %%
# ----- 2. Fine-tune pretrained model -----#
# Define Trainer parameters
def compute_metrics(p):
    pred, labels = p
    pred = np.argmax(pred, axis=1)

    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    recall = recall_score(y_true=labels, y_pred=pred, average='weighted')
    precision = precision_score(y_true=labels, y_pred=pred, average = 'weighted')
    f1 = f1_score(y_true=labels, y_pred=pred, average = 'weighted')

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1, }

# %%
# Define Trainer

args = TrainingArguments(
    output_dir="D:\COS 802\Project\Electra Training\output",
    evaluation_strategy="steps",
    eval_steps=50,
    logging_steps = 50,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=2,
    seed=0,
    load_best_model_at_end=True,
    report_to="wandb",  # enable logging to W&B
    run_name="electra"  # name of the W&B run (optional)
)
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
    #callbacks=[EarlyStoppingCallback(early_stopping_patience=3)],
)

# %%
# Train pre-trained model
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 17348
#   Num Epochs = 2
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2170
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: jesseparvess-elucidate (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">electra</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jesseparvess-elucidate/huggingface" target="_blank">https://wandb.ai/jesseparvess-elucidate/huggingface</a><br/>
#                 Run page: <a href="https://wandb.ai/jesseparvess-elucidate/huggingface/runs/2f3ksell" target="_blank">https://wandb.ai/jesseparvess-elucidate/huggingface/runs/2f3ksell</a><br/>
#                 Run data is saved locally in <code>C:\Users\jesse\Documents\Masters\COS 802\Project\Fitted Transformers\ELECTRA\wandb\run-20211111_091150-2f3ksell</code><br/><br/>
#     <div>
#
#       <progress value='2170' max='2170' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2170/2170 1:20:14, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.830500</td>
#       <td>0.674139</td>
#       <td>0.773742</td>
#       <td>0.598677</td>
#       <td>0.773742</td>
#       <td>0.675044</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.586300</td>
#       <td>0.481176</td>
#       <td>0.872747</td>
#       <td>0.823589</td>
#       <td>0.872747</td>
#       <td>0.847438</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.461500</td>
#       <td>0.398478</td>
#       <td>0.868711</td>
#       <td>0.842854</td>
#       <td>0.868711</td>
#       <td>0.849687</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.389000</td>
#       <td>0.391679</td>
#       <td>0.872209</td>
#       <td>0.839248</td>
#       <td>0.872209</td>
#       <td>0.851739</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.424900</td>
#       <td>0.367345</td>
#       <td>0.877589</td>
#       <td>0.846089</td>
#       <td>0.877589</td>
#       <td>0.857086</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.401600</td>
#       <td>0.364177</td>
#       <td>0.892386</td>
#       <td>0.842219</td>
#       <td>0.892386</td>
#       <td>0.866536</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.401700</td>
#       <td>0.331368</td>
#       <td>0.896153</td>
#       <td>0.852770</td>
#       <td>0.896153</td>
#       <td>0.872050</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.335000</td>
#       <td>0.345688</td>
#       <td>0.896960</td>
#       <td>0.847452</td>
#       <td>0.896960</td>
#       <td>0.871288</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.410000</td>
#       <td>0.330257</td>
#       <td>0.895615</td>
#       <td>0.844845</td>
#       <td>0.895615</td>
#       <td>0.869478</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.344200</td>
#       <td>0.333411</td>
#       <td>0.893193</td>
#       <td>0.841202</td>
#       <td>0.893193</td>
#       <td>0.865986</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.305700</td>
#       <td>0.320989</td>
#       <td>0.900995</td>
#       <td>0.850073</td>
#       <td>0.900995</td>
#       <td>0.874762</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.339000</td>
#       <td>0.313170</td>
#       <td>0.903955</td>
#       <td>0.854659</td>
#       <td>0.903955</td>
#       <td>0.878169</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.368400</td>
#       <td>0.322853</td>
#       <td>0.903417</td>
#       <td>0.853703</td>
#       <td>0.903417</td>
#       <td>0.877538</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.329200</td>
#       <td>0.313098</td>
#       <td>0.903955</td>
#       <td>0.855187</td>
#       <td>0.903955</td>
#       <td>0.878285</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.289000</td>
#       <td>0.308013</td>
#       <td>0.903955</td>
#       <td>0.852951</td>
#       <td>0.903955</td>
#       <td>0.877665</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.320200</td>
#       <td>0.302835</td>
#       <td>0.905569</td>
#       <td>0.856738</td>
#       <td>0.905569</td>
#       <td>0.879835</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.325900</td>
#       <td>0.291387</td>
#       <td>0.906376</td>
#       <td>0.857131</td>
#       <td>0.906376</td>
#       <td>0.880537</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.367700</td>
#       <td>0.317584</td>
#       <td>0.903148</td>
#       <td>0.851974</td>
#       <td>0.903148</td>
#       <td>0.876795</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.359000</td>
#       <td>0.285000</td>
#       <td>0.905300</td>
#       <td>0.857050</td>
#       <td>0.905300</td>
#       <td>0.879701</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.265500</td>
#       <td>0.289701</td>
#       <td>0.906645</td>
#       <td>0.857738</td>
#       <td>0.906645</td>
#       <td>0.880855</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.298900</td>
#       <td>0.305413</td>
#       <td>0.903955</td>
#       <td>0.851952</td>
#       <td>0.903955</td>
#       <td>0.877089</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.306300</td>
#       <td>0.285072</td>
#       <td>0.906107</td>
#       <td>0.856371</td>
#       <td>0.906107</td>
#       <td>0.880148</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.276000</td>
#       <td>0.300550</td>
#       <td>0.906376</td>
#       <td>0.856525</td>
#       <td>0.906376</td>
#       <td>0.880379</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.237100</td>
#       <td>0.298264</td>
#       <td>0.906645</td>
#       <td>0.855230</td>
#       <td>0.906645</td>
#       <td>0.880168</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.280300</td>
#       <td>0.304519</td>
#       <td>0.905031</td>
#       <td>0.853493</td>
#       <td>0.905031</td>
#       <td>0.878505</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.271400</td>
#       <td>0.297270</td>
#       <td>0.905838</td>
#       <td>0.854569</td>
#       <td>0.905838</td>
#       <td>0.879425</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.296900</td>
#       <td>0.296962</td>
#       <td>0.906107</td>
#       <td>0.889410</td>
#       <td>0.906107</td>
#       <td>0.891346</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.323600</td>
#       <td>0.284966</td>
#       <td>0.907183</td>
#       <td>0.890953</td>
#       <td>0.907183</td>
#       <td>0.891227</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.304300</td>
#       <td>0.265903</td>
#       <td>0.905838</td>
#       <td>0.854816</td>
#       <td>0.905838</td>
#       <td>0.879504</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.231000</td>
#       <td>0.286357</td>
#       <td>0.906645</td>
#       <td>0.855798</td>
#       <td>0.906645</td>
#       <td>0.880368</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.304300</td>
#       <td>0.276429</td>
#       <td>0.908259</td>
#       <td>0.892457</td>
#       <td>0.908259</td>
#       <td>0.888304</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.289900</td>
#       <td>0.282029</td>
#       <td>0.907721</td>
#       <td>0.899139</td>
#       <td>0.907721</td>
#       <td>0.884733</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.279900</td>
#       <td>0.264519</td>
#       <td>0.910681</td>
#       <td>0.897883</td>
#       <td>0.910681</td>
#       <td>0.893740</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.259100</td>
#       <td>0.294811</td>
#       <td>0.902072</td>
#       <td>0.888178</td>
#       <td>0.902072</td>
#       <td>0.884168</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.315300</td>
#       <td>0.272300</td>
#       <td>0.912295</td>
#       <td>0.903092</td>
#       <td>0.912295</td>
#       <td>0.895817</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.230400</td>
#       <td>0.274999</td>
#       <td>0.909874</td>
#       <td>0.907126</td>
#       <td>0.909874</td>
#       <td>0.885657</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.295900</td>
#       <td>0.262129</td>
#       <td>0.911488</td>
#       <td>0.898102</td>
#       <td>0.911488</td>
#       <td>0.890251</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.257600</td>
#       <td>0.265724</td>
#       <td>0.909605</td>
#       <td>0.903909</td>
#       <td>0.909605</td>
#       <td>0.884749</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.264700</td>
#       <td>0.267520</td>
#       <td>0.912026</td>
#       <td>0.899436</td>
#       <td>0.912026</td>
#       <td>0.887380</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.265400</td>
#       <td>0.271356</td>
#       <td>0.909605</td>
#       <td>0.858443</td>
#       <td>0.909605</td>
#       <td>0.883225</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.242300</td>
#       <td>0.271122</td>
#       <td>0.908797</td>
#       <td>0.857800</td>
#       <td>0.908797</td>
#       <td>0.882525</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.258900</td>
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-50
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-50\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-50\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-100
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-100\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-150
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-150\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-150\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-200
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-200\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-200\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-250
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-250\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-250\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-300
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-300\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-300\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-350
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-350\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-350\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-400
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-400\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-400\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-450
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-450\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-450\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-500
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-500\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-500\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-550
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-550\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-550\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-600
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-600\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-600\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-650
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-650\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-650\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-700
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-700\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-700\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-750
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-750\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-750\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-800
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-800\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-800\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-850
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-850\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-850\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-900
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-900\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-900\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-950
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-950\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-950\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1000
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1000\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1050
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1050\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1050\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1100
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1100\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1150
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1150\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1150\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1200
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1200\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1200\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1250
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1250\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1250\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1300
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1300\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1300\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1350
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1350\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1350\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1400
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1400\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1400\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1450
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1450\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1450\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1500
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1500\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1500\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1550
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1550\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1550\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1600
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1600\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1600\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1650
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1650\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1650\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1700
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1700\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1700\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1750
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1750\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1750\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1800
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1800\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1800\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1850
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1850\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1850\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1900
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1900\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1900\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-1950
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-1950\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-1950\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-2000
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-2000\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-2000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-2050
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-2050\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-2050\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-2100
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-2100\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-2100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Electra Training\output\checkpoint-2150
# Configuration saved in D:\COS 802\Project\Electra Training\output\checkpoint-2150\config.json
# Model weights saved in D:\COS 802\Project\Electra Training\output\checkpoint-2150\pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from D:\COS 802\Project\Electra Training\output\checkpoint-1850 (score: 0.26212894916534424).
# TrainOutput(global_step=2170, training_loss=0.33052068349952524, metrics={'train_runtime': 4824.0943, 'train_samples_per_second': 7.192, 'train_steps_per_second': 0.45, 'total_flos': 137564875614672.0, 'train_loss': 0.33052068349952524, 'epoch': 2.0})

# %%
# ----- 3. Predict -----#
# Load test data

X_test = list(df_test['text'])
y_test = list(df_test['label'])

X_test_tokenized = tokenizer(X_test, padding=True, truncation=True, max_length=512)

# %%
# Create torch dataset
test_dataset = Dataset(X_test_tokenized)

# %%
# Load trained model
model_path = "D:\COS 802\Project\Electra Training\output\checkpoint-1850"
model = ElectraForSequenceClassification.from_pretrained(model_path, num_labels=3)
# Out:
# loading configuration file D:\COS 802\Project\Electra Training\output\checkpoint-1850\config.json
# Model config ElectraConfig {
#   "_name_or_path": "google/electra-small-discriminator",
#   "architectures": [
#     "ElectraForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "embedding_size": 128,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 256,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 1024,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "electra",
#   "num_attention_heads": 4,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "summary_activation": "gelu",
#   "summary_last_dropout": 0.1,
#   "summary_type": "first",
#   "summary_use_proj": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.10.3",
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# loading weights file D:\COS 802\Project\Electra Training\output\checkpoint-1850\pytorch_model.bin
# All model checkpoint weights were used when initializing ElectraForSequenceClassification.
#
# All the weights of ElectraForSequenceClassification were initialized from the model checkpoint at D:\COS 802\Project\Electra Training\output\checkpoint-1850.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use ElectraForSequenceClassification for predictions without further training.

# %%
# Define test trainer
test_trainer = Trainer(model)
# Out:
# No `TrainingArguments` passed, using `output_dir=tmp_trainer`.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
# Make prediction
raw_pred, _, _ = test_trainer.predict(test_dataset)

# Preprocess raw predictions
y_pred = np.argmax(raw_pred, axis=1)
# Out:
# ***** Running Prediction *****
#   Num examples = 3718
#   Batch size = 8
#     <div>
#
#       <progress value='53' max='465' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 53/465 00:06 < 00:51, 7.98 it/s]
#     </div>

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_test, y_pred)

# %%
print(classification_report(y_test,y_pred))
