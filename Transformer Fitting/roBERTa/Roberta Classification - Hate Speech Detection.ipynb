# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, matthews_corrcoef
import torch
from transformers import TrainingArguments, Trainer
from transformers import RobertaTokenizer, RobertaForSequenceClassification
from transformers import EarlyStoppingCallback

# %% [markdown]
# ### Load Data Set

# %%
df_train = pd.read_csv('training.csv')
df_val = pd.read_csv('validation.csv')
df_test = pd.read_csv('testing.csv')

df_train.head()
# Out:
#    Unnamed: 0                                               text  label
# 0       19429  retweet mentionhere: people be like from bae t...      1
# 1       10662  i like being teased, do not give me the pussy ...      1
# 2       19558         retweet mentionhere: you are jealous bitch      1
# 3        2909  mentionhere cuz people at work are bitches the...      1
# 4       24378  quote this with your best racist comment i nee...      1

# %%
# Define pretrained tokenizer and model

model_name = "roberta-base"

tokenizer = RobertaTokenizer.from_pretrained(model_name)

model = RobertaForSequenceClassification.from_pretrained(model_name, num_labels=3)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'lm_head.dense.bias', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'roberta.pooler.dense.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.weight', 'classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# ----- 1. Preprocess data -----#
# Preprocess data

X_train = list(df_train["text"])
y_train = list(df_train["label"])

X_val = list(df_val["text"])
y_val = list(df_val["label"])

X_train_tokenized = tokenizer(X_train, padding=True, truncation=True, max_length=512)
X_val_tokenized = tokenizer(X_val, padding=True, truncation=True, max_length=512)

# %%
# Create torch dataset
class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels=None):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        if self.labels:
            item["labels"] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.encodings["input_ids"])

# %%
train_dataset = Dataset(X_train_tokenized, y_train)
val_dataset = Dataset(X_val_tokenized, y_val)

# %%
# ----- 2. Fine-tune pretrained model -----#
# Define Trainer parameters
def compute_metrics(p):
    pred, labels = p
    pred = np.argmax(pred, axis=1)

    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    recall = recall_score(y_true=labels, y_pred=pred, average='weighted')
    precision = precision_score(y_true=labels, y_pred=pred, average = 'weighted')
    f1 = f1_score(y_true=labels, y_pred=pred, average = 'weighted')

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1, }

# %%
# Define Trainer

args = TrainingArguments(
    output_dir="D:\COS 802\Project\Roberta Training\output",
    evaluation_strategy="steps",
    eval_steps=50,
    logging_steps = 50,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=2,
    seed=0,
    load_best_model_at_end=True,
    report_to="wandb",  # enable logging to W&B
    run_name="roberta-base"  # name of the W&B run (optional)
)
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
    #callbacks=[EarlyStoppingCallback(early_stopping_patience=3)],
)

# %%
# Train pre-trained model
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 17348
#   Num Epochs = 2
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2170
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: jesseparvess-elucidate (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">roberta-base</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jesseparvess-elucidate/huggingface" target="_blank">https://wandb.ai/jesseparvess-elucidate/huggingface</a><br/>
#                 Run page: <a href="https://wandb.ai/jesseparvess-elucidate/huggingface/runs/bxjv9ibw" target="_blank">https://wandb.ai/jesseparvess-elucidate/huggingface/runs/bxjv9ibw</a><br/>
#                 Run data is saved locally in <code>C:\Users\jesse\Documents\Masters\COS 802\Project\Fitted Transformers\roBERTa\wandb\run-20211108_102855-bxjv9ibw</code><br/><br/>
#     <div>
#
#       <progress value='2170' max='2170' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2170/2170 6:59:01, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.581300</td>
#       <td>0.390303</td>
#       <td>0.876513</td>
#       <td>0.824392</td>
#       <td>0.876513</td>
#       <td>0.848804</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.403400</td>
#       <td>0.433790</td>
#       <td>0.888351</td>
#       <td>0.836452</td>
#       <td>0.888351</td>
#       <td>0.860848</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.417200</td>
#       <td>0.348669</td>
#       <td>0.897229</td>
#       <td>0.850592</td>
#       <td>0.897229</td>
#       <td>0.872272</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.358800</td>
#       <td>0.318347</td>
#       <td>0.900995</td>
#       <td>0.852978</td>
#       <td>0.900995</td>
#       <td>0.875590</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.385600</td>
#       <td>0.346133</td>
#       <td>0.899919</td>
#       <td>0.850261</td>
#       <td>0.899919</td>
#       <td>0.874109</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.382700</td>
#       <td>0.347852</td>
#       <td>0.898574</td>
#       <td>0.846838</td>
#       <td>0.898574</td>
#       <td>0.871839</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.335700</td>
#       <td>0.294768</td>
#       <td>0.902879</td>
#       <td>0.851565</td>
#       <td>0.902879</td>
#       <td>0.876463</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.355000</td>
#       <td>0.401116</td>
#       <td>0.899919</td>
#       <td>0.891151</td>
#       <td>0.899919</td>
#       <td>0.875646</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.398100</td>
#       <td>0.311934</td>
#       <td>0.904762</td>
#       <td>0.853830</td>
#       <td>0.904762</td>
#       <td>0.878475</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.348800</td>
#       <td>0.296912</td>
#       <td>0.902879</td>
#       <td>0.851093</td>
#       <td>0.902879</td>
#       <td>0.876184</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.296700</td>
#       <td>0.301346</td>
#       <td>0.906376</td>
#       <td>0.886498</td>
#       <td>0.906376</td>
#       <td>0.889367</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.337700</td>
#       <td>0.314666</td>
#       <td>0.903148</td>
#       <td>0.870880</td>
#       <td>0.903148</td>
#       <td>0.881101</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.353800</td>
#       <td>0.330856</td>
#       <td>0.903417</td>
#       <td>0.886802</td>
#       <td>0.903417</td>
#       <td>0.886782</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.325100</td>
#       <td>0.288161</td>
#       <td>0.906376</td>
#       <td>0.891322</td>
#       <td>0.906376</td>
#       <td>0.884205</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.271800</td>
#       <td>0.331539</td>
#       <td>0.903686</td>
#       <td>0.881903</td>
#       <td>0.903686</td>
#       <td>0.880443</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.310100</td>
#       <td>0.306098</td>
#       <td>0.898036</td>
#       <td>0.846254</td>
#       <td>0.898036</td>
#       <td>0.871026</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.296500</td>
#       <td>0.306593</td>
#       <td>0.904762</td>
#       <td>0.880779</td>
#       <td>0.904762</td>
#       <td>0.882124</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.356600</td>
#       <td>0.303242</td>
#       <td>0.907721</td>
#       <td>0.856254</td>
#       <td>0.907721</td>
#       <td>0.881211</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.328400</td>
#       <td>0.285300</td>
#       <td>0.905569</td>
#       <td>0.901324</td>
#       <td>0.905569</td>
#       <td>0.902734</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.252000</td>
#       <td>0.296158</td>
#       <td>0.908259</td>
#       <td>0.887235</td>
#       <td>0.908259</td>
#       <td>0.890554</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.291700</td>
#       <td>0.287148</td>
#       <td>0.909335</td>
#       <td>0.886656</td>
#       <td>0.909335</td>
#       <td>0.892351</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.293300</td>
#       <td>0.269921</td>
#       <td>0.908528</td>
#       <td>0.900821</td>
#       <td>0.908528</td>
#       <td>0.903319</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.265800</td>
#       <td>0.303692</td>
#       <td>0.907721</td>
#       <td>0.882896</td>
#       <td>0.907721</td>
#       <td>0.883492</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.212900</td>
#       <td>0.288379</td>
#       <td>0.911219</td>
#       <td>0.890727</td>
#       <td>0.911219</td>
#       <td>0.889141</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.249300</td>
#       <td>0.317389</td>
#       <td>0.907990</td>
#       <td>0.888122</td>
#       <td>0.907990</td>
#       <td>0.888995</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.263100</td>
#       <td>0.307740</td>
#       <td>0.906914</td>
#       <td>0.893868</td>
#       <td>0.906914</td>
#       <td>0.898675</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.303600</td>
#       <td>0.293349</td>
#       <td>0.910681</td>
#       <td>0.904749</td>
#       <td>0.910681</td>
#       <td>0.907207</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.308300</td>
#       <td>0.276592</td>
#       <td>0.914985</td>
#       <td>0.902600</td>
#       <td>0.914985</td>
#       <td>0.904149</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.274800</td>
#       <td>0.269443</td>
#       <td>0.912295</td>
#       <td>0.898735</td>
#       <td>0.912295</td>
#       <td>0.901544</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.230900</td>
#       <td>0.282560</td>
#       <td>0.914716</td>
#       <td>0.903746</td>
#       <td>0.914716</td>
#       <td>0.905907</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.283000</td>
#       <td>0.273920</td>
#       <td>0.912833</td>
#       <td>0.901851</td>
#       <td>0.912833</td>
#       <td>0.905108</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.260900</td>
#       <td>0.284327</td>
#       <td>0.909874</td>
#       <td>0.858115</td>
#       <td>0.909874</td>
#       <td>0.883228</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.279600</td>
#       <td>0.262675</td>
#       <td>0.910143</td>
#       <td>0.895234</td>
#       <td>0.910143</td>
#       <td>0.895736</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.250600</td>
#       <td>0.286932</td>
#       <td>0.907721</td>
#       <td>0.899249</td>
#       <td>0.907721</td>
#       <td>0.901407</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.286300</td>
#       <td>0.280502</td>
#       <td>0.915254</td>
#       <td>0.905292</td>
#       <td>0.915254</td>
#       <td>0.906673</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.209900</td>
#       <td>0.293459</td>
#       <td>0.907183</td>
#       <td>0.855155</td>
#       <td>0.907183</td>
#       <td>0.880261</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.269000</td>
#       <td>0.269890</td>
#       <td>0.913640</td>
#       <td>0.904278</td>
#       <td>0.913640</td>
#       <td>0.907009</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.243000</td>
#       <td>0.271502</td>
#       <td>0.911488</td>
#       <td>0.859464</td>
#       <td>0.911488</td>
#       <td>0.884711</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.248800</td>
#       <td>0.272950</td>
#       <td>0.910950</td>
#       <td>0.887982</td>
#       <td>0.910950</td>
#       <td>0.884837</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.272300</td>
#       <td>0.266581</td>
#       <td>0.910412</td>
#       <td>0.887334</td>
#       <td>0.910412</td>
#       <td>0.884659</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.231800</td>
#       <td>0.268366</td>
#       <td>0.911488</td>
#       <td>0.885969</td>
#       <td>0.911488</td>
#       <td>0.886879</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.229200</td>
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-50
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-50\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-50\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-100
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-100\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-150
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-150\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-150\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-200
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-200\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-200\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-250
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-250\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-250\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-300
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-300\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-300\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-350
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-350\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-350\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-400
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-400\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-400\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-450
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-450\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-450\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-500
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-500\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-500\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-550
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-550\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-550\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-600
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-600\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-600\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-650
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-650\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-650\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-700
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-700\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-700\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-750
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-750\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-750\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-800
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-800\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-800\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-850
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-850\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-850\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-900
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-900\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-900\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-950
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-950\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-950\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1000
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1000\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1050
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1050\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1050\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1100
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1100\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1150
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1150\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1150\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1200
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1200\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1200\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1250
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1250\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1250\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1300
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1300\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1300\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1350
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1350\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1350\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1400
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1400\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1400\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1450
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1450\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1450\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1500
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1500\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1500\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1550
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1550\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1550\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1600
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1600\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1600\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1650
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1650\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1650\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1700
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1700\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1700\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1750
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1750\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1750\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1800
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1800\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1800\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1850
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1850\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1850\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1900
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1900\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1900\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-1950
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1950\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-1950\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-2000
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-2000\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-2000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-2050
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-2050\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-2050\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-2100
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-2100\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-2100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Roberta Training\output\checkpoint-2150
# Configuration saved in D:\COS 802\Project\Roberta Training\output\checkpoint-2150\config.json
# Model weights saved in D:\COS 802\Project\Roberta Training\output\checkpoint-2150\pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from D:\COS 802\Project\Roberta Training\output\checkpoint-1650 (score: 0.2626747786998749).
# TrainOutput(global_step=2170, training_loss=0.3051774255691036, metrics={'train_runtime': 25154.1013, 'train_samples_per_second': 1.379, 'train_steps_per_second': 0.086, 'total_flos': 1123292847488112.0, 'train_loss': 0.3051774255691036, 'epoch': 2.0})

# %%
# ----- 3. Predict -----#
# Load test data

X_test = list(df_test['text'])
y_test = list(df_test['label'])

X_test_tokenized = tokenizer(X_test, padding=True, truncation=True, max_length=512)

# %%
# Create torch dataset
test_dataset = Dataset(X_test_tokenized)

# %%
# Load trained model
model_path = "D:\COS 802\Project\Roberta Training\output\checkpoint-1350"
model = RobertaForSequenceClassification.from_pretrained(model_path, num_labels=3)
# Out:
# loading configuration file D:\COS 802\Project\Roberta Training\output\checkpoint-1350\config.json
# Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "torch_dtype": "float32",
#   "transformers_version": "4.10.3",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file D:\COS 802\Project\Roberta Training\output\checkpoint-1350\pytorch_model.bin
# All model checkpoint weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the model checkpoint at D:\COS 802\Project\Roberta Training\output\checkpoint-1350.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.

# %%
# Define test trainer
test_trainer = Trainer(model)
# Out:
# No `TrainingArguments` passed, using `output_dir=tmp_trainer`.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
# Make prediction
raw_pred, _, _ = test_trainer.predict(test_dataset)

# Preprocess raw predictions
y_pred = np.argmax(raw_pred, axis=1)
# Out:
# ***** Running Prediction *****
#   Num examples = 3718
#   Batch size = 8
#     <div>
#
#       <progress value='465' max='465' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [465/465 05:01]
#     </div>

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[  65,  122,   26],
#        [  70, 2770,   65],
#        [  17,   38,  545]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.31      0.36       213
#            1       0.95      0.95      0.95      2905
#            2       0.86      0.91      0.88       600
#
#     accuracy                           0.91      3718
#    macro avg       0.74      0.72      0.73      3718
# weighted avg       0.90      0.91      0.90      3718
