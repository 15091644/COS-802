# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, matthews_corrcoef
import torch
from transformers import TrainingArguments, Trainer
from transformers import AlbertTokenizer, AlbertForSequenceClassification
from transformers import EarlyStoppingCallback

# %% [markdown]
# ### Load Data Set

# %%
df_train = pd.read_csv('training.csv')
df_val = pd.read_csv('validation.csv')
df_test = pd.read_csv('testing.csv')

df_train.head()
# Out:
#    Unnamed: 0                                               text  label
# 0       19429  retweet mentionhere: people be like from bae t...      1
# 1       10662  i like being teased, do not give me the pussy ...      1
# 2       19558         retweet mentionhere: you are jealous bitch      1
# 3        2909  mentionhere cuz people at work are bitches the...      1
# 4       24378  quote this with your best racist comment i nee...      1

# %%
# Define pretrained tokenizer and model

model_name = 'albert-base-v2'

tokenizer = AlbertTokenizer.from_pretrained(model_name)

model = AlbertForSequenceClassification.from_pretrained(model_name, num_labels=3)
# Out:
# Downloading:   0%|          | 0.00/760k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/684 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/47.4M [00:00<?, ?B/s]
# Some weights of the model checkpoint at albert-base-v2 were not used when initializing AlbertForSequenceClassification: ['predictions.decoder.weight', 'predictions.decoder.bias', 'predictions.LayerNorm.weight', 'predictions.LayerNorm.bias', 'predictions.dense.bias', 'predictions.bias', 'predictions.dense.weight']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at albert-base-v2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# ----- 1. Preprocess data -----#
# Preprocess data

X_train = list(df_train["text"])
y_train = list(df_train["label"])

X_val = list(df_val["text"])
y_val = list(df_val["label"])

X_train_tokenized = tokenizer(X_train, padding=True, truncation=True, max_length=512)
X_val_tokenized = tokenizer(X_val, padding=True, truncation=True, max_length=512)

# %%
# Create torch dataset
class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels=None):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        if self.labels:
            item["labels"] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.encodings["input_ids"])

# %%
train_dataset = Dataset(X_train_tokenized, y_train)
val_dataset = Dataset(X_val_tokenized, y_val)

# %%
# ----- 2. Fine-tune pretrained model -----#
# Define Trainer parameters
def compute_metrics(p):
    pred, labels = p
    pred = np.argmax(pred, axis=1)

    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    recall = recall_score(y_true=labels, y_pred=pred, average='weighted')
    precision = precision_score(y_true=labels, y_pred=pred, average = 'weighted')
    f1 = f1_score(y_true=labels, y_pred=pred, average = 'weighted')

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1, }

# %%
# Define Trainer

args = TrainingArguments(
    output_dir="D:\COS 802\Project\Albert Training\output",
    evaluation_strategy="steps",
    eval_steps=50,
    logging_steps = 50,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=2,
    seed=0,
    load_best_model_at_end=True,
    report_to="wandb",  # enable logging to W&B
    run_name="albert"  # name of the W&B run (optional)
)
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
    #callbacks=[EarlyStoppingCallback(early_stopping_patience=3)],
)

# %%
# Train pre-trained model
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 17348
#   Num Epochs = 2
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2170
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: jesseparvess-elucidate (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">albert</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai
anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-50
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-50\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-50\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-100
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-100\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-150
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-150\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-150\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-200
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-200\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-200\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-250
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-250\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-250\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-300
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-300\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-300\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-350
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-350\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-350\pytorch_model.bin
# wandb: Network error resolved after 2:14:49.390916, resuming normal operation.
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-400
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-400\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-400\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-450
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-450\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-450\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-500
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-500\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-500\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-550
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-550\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-550\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-600
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-600\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-600\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-650
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-650\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-650\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# wandb: 500 encountered ({"error":"Error 1135: Can't create a new thread (errno 11); if you are not out of available memory, you can consult the manual for a possible OS-dependent bug"}), retrying request
# wandb: Network error resolved after 0:11:31.431235, resuming normal operation.
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-700
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-700\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-700\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-750
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-750\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-750\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# wandb: Network error resolved after 0:00:08.722674, resuming normal operation.
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-800
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-800\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-800\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-850
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-850\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-850\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-900
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-900\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-900\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-950
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-950\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-950\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# wandb: Network error resolved after 0:34:53.754443, resuming normal operation.
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1000
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1000\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1050
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1050\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1050\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1100
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1100\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1150
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1150\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1150\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1200
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1200\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1200\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1250
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1250\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1250\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1300
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1300\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1300\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1350
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1350\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1350\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1400
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1400\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1400\pytorch_model.bin
# wandb: Network error resolved after 0:01:23.156971, resuming normal operation.
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1450
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1450\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1450\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1500
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1500\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1500\pytorch_model.bin
# wandb: Network error resolved after 0:02:10.994996, resuming normal operation.
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1550
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1550\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1550\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1600
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1600\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1600\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1650
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1650\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1650\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1700
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1700\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1700\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1750
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1750\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1750\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1800
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1800\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1800\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1850
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1850\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1850\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1900
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1900\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1900\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-1950
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-1950\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-1950\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-2000
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-2000\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-2000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-2050
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-2050\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-2050\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-2100
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-2100\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-2100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Albert Training\output\checkpoint-2150
# Configuration saved in D:\COS 802\Project\Albert Training\output\checkpoint-2150\config.json
# Model weights saved in D:\COS 802\Project\Albert Training\output\checkpoint-2150\pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from D:\COS 802\Project\Albert Training\output\checkpoint-2150 (score: 0.2702058255672455).
# TrainOutput(global_step=2170, training_loss=0.3365783522205968, metrics={'train_runtime': 80334.0793, 'train_samples_per_second': 0.432, 'train_steps_per_second': 0.027, 'total_flos': 163582618831824.0, 'train_loss': 0.3365783522205968, 'epoch': 2.0})

# %%
# ----- 3. Predict -----#
# Load test data

X_test = list(df_test['text'])
y_test = list(df_test['label'])

X_test_tokenized = tokenizer(X_test, padding=True, truncation=True, max_length=512)

# %%
# Create torch dataset
test_dataset = Dataset(X_test_tokenized)

# %%
# Load trained model
model_path = "D:\COS 802\Project\Albert Training\output\checkpoint-1350"
model = AlbertForSequenceClassification.from_pretrained(model_path, num_labels=3)
# Out:
# loading configuration file D:\COS 802\Project\Albert Training\output\checkpoint-1350\config.json
# Model config AlbertConfig {
#   "_name_or_path": "albert-base-v2",
#   "architectures": [
#     "AlbertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0,
#   "bos_token_id": 2,
#   "classifier_dropout_prob": 0.1,
#   "down_scale_factor": 1,
#   "embedding_size": 128,
#   "eos_token_id": 3,
#   "gap_size": 0,
#   "hidden_act": "gelu_new",
#   "hidden_dropout_prob": 0,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "inner_group_num": 1,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "albert",
#   "net_structure_type": 0,
#   "num_attention_heads": 12,
#   "num_hidden_groups": 1,
#   "num_hidden_layers": 12,
#   "num_memory_blocks": 0,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "torch_dtype": "float32",
#   "transformers_version": "4.10.3",
#   "type_vocab_size": 2,
#   "vocab_size": 30000
# }
#
# loading weights file D:\COS 802\Project\Albert Training\output\checkpoint-1350\pytorch_model.bin
# All model checkpoint weights were used when initializing AlbertForSequenceClassification.
#
# All the weights of AlbertForSequenceClassification were initialized from the model checkpoint at D:\COS 802\Project\Albert Training\output\checkpoint-1350.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AlbertForSequenceClassification for predictions without further training.

# %%
# Define test trainer
test_trainer = Trainer(model)
# Out:
# No `TrainingArguments` passed, using `output_dir=tmp_trainer`.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
# Make prediction
raw_pred, _, _ = test_trainer.predict(test_dataset)

# Preprocess raw predictions
y_pred = np.argmax(raw_pred, axis=1)
# Out:
# ***** Running Prediction *****
#   Num examples = 3718
#   Batch size = 8
#     <div>
#
#       <progress value='465' max='465' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [465/465 21:58]
#     </div>
# wandb: Network error resolved after 0:00:40.303726, resuming normal operation.
# wandb: Network error resolved after 0:00:50.173427, resuming normal operation.

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[  38,  132,   43],
#        [  42, 2755,  108],
#        [   5,   29,  566]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.18      0.26       213
#            1       0.94      0.95      0.95      2905
#            2       0.79      0.94      0.86       600
#
#     accuracy                           0.90      3718
#    macro avg       0.73      0.69      0.69      3718
# weighted avg       0.89      0.90      0.89      3718
