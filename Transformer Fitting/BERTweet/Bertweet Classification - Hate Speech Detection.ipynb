# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, matthews_corrcoef
import torch
import tensorflow
from transformers import TrainingArguments, Trainer
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from transformers import EarlyStoppingCallback

# %% [markdown]
# ### Load Data Set

# %%
df_train = pd.read_csv('training.csv')
df_val = pd.read_csv('validation.csv')
df_test = pd.read_csv('testing.csv')

df_train.head()
# Out:
#    Unnamed: 0                                               text  label
# 0       19429  retweet mentionhere: people be like from bae t...      1
# 1       10662  i like being teased, do not give me the pussy ...      1
# 2       19558         retweet mentionhere: you are jealous bitch      1
# 3        2909  mentionhere cuz people at work are bitches the...      1
# 4       24378  quote this with your best racist comment i nee...      1

# %%
# Define pretrained tokenizer and model

model_name = "vinai/bertweet-base"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=3,from_tf=True)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# All TF 2.0 model weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the TF 2.0 model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.

# %%
# ----- 1. Preprocess data -----#
# Preprocess data

X_train = list(df_train["text"])
y_train = list(df_train["label"])

X_val = list(df_val["text"])
y_val = list(df_val["label"])

X_train_tokenized = tokenizer(X_train, padding=True, truncation=True, max_length=512)
X_val_tokenized = tokenizer(X_val, padding=True, truncation=True, max_length=512)

# %%
# Create torch dataset
class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels=None):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        if self.labels:
            item["labels"] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.encodings["input_ids"])

# %%
train_dataset = Dataset(X_train_tokenized, y_train)
val_dataset = Dataset(X_val_tokenized, y_val)

# %%
# ----- 2. Fine-tune pretrained model -----#
# Define Trainer parameters
def compute_metrics(p):
    pred, labels = p
    pred = np.argmax(pred, axis=1)

    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    recall = recall_score(y_true=labels, y_pred=pred, average='weighted')
    precision = precision_score(y_true=labels, y_pred=pred, average = 'weighted')
    f1 = f1_score(y_true=labels, y_pred=pred, average = 'weighted')

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1, }

# %%
# Define Trainer

args = TrainingArguments(
    output_dir="D:\COS 802\Project\Bertweet2 Training\output",
    evaluation_strategy="steps",
    eval_steps=100,
    logging_steps = 1000,
    per_device_train_batch_size=16*2,
    per_device_eval_batch_size=16*2,
    num_train_epochs=2,
    seed=0,
    load_best_model_at_end=True,
    report_to="wandb",  # enable logging to W&B
    run_name="bertweet2"  # name of the W&B run (optional)
)
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
    #callbacks=[EarlyStoppingCallback(early_stopping_patience=3)],
)

# %%
# Train pre-trained model
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 17348
#   Num Epochs = 2
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2170
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: jesseparvess-elucidate (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">bertweet</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jesseparvess-elucidate/huggingface" target="_blank">https://wandb.ai/jesseparvess-elucidate/huggingface</a><br/>
#                 Run page: <a href="https://wandb.ai/jesseparvess-elucidate/huggingface/runs/zezgqz03" target="_blank">https://wandb.ai/jesseparvess-elucidate/huggingface/runs/zezgqz03</a><br/>
#                 Run data is saved locally in <code>C:\Users\jesse\Documents\Masters\COS 802\Project\Fitted Transformers\BERTweet\wandb\run-20211111_120208-zezgqz03</code><br/><br/>
#     <div>
#
#       <progress value='2170' max='2170' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2170/2170 8:05:19, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.624000</td>
#       <td>0.438440</td>
#       <td>0.870056</td>
#       <td>0.818656</td>
#       <td>0.870056</td>
#       <td>0.843293</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.440600</td>
#       <td>0.399182</td>
#       <td>0.857143</td>
#       <td>0.841575</td>
#       <td>0.857143</td>
#       <td>0.840444</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.383800</td>
#       <td>0.390582</td>
#       <td>0.894808</td>
#       <td>0.844091</td>
#       <td>0.894808</td>
#       <td>0.868698</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.332900</td>
#       <td>0.315801</td>
#       <td>0.905300</td>
#       <td>0.854657</td>
#       <td>0.905300</td>
#       <td>0.879117</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.352400</td>
#       <td>0.343011</td>
#       <td>0.905569</td>
#       <td>0.857128</td>
#       <td>0.905569</td>
#       <td>0.879952</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.386900</td>
#       <td>0.319704</td>
#       <td>0.903417</td>
#       <td>0.851993</td>
#       <td>0.903417</td>
#       <td>0.876949</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.323300</td>
#       <td>0.312801</td>
#       <td>0.904493</td>
#       <td>0.853048</td>
#       <td>0.904493</td>
#       <td>0.878012</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.326900</td>
#       <td>0.411967</td>
#       <td>0.892117</td>
#       <td>0.897648</td>
#       <td>0.892117</td>
#       <td>0.864852</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.369700</td>
#       <td>0.323510</td>
#       <td>0.905031</td>
#       <td>0.853448</td>
#       <td>0.905031</td>
#       <td>0.878482</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.304400</td>
#       <td>0.322675</td>
#       <td>0.900995</td>
#       <td>0.849126</td>
#       <td>0.900995</td>
#       <td>0.874155</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.282600</td>
#       <td>0.347055</td>
#       <td>0.901533</td>
#       <td>0.849666</td>
#       <td>0.901533</td>
#       <td>0.874411</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.340600</td>
#       <td>0.298186</td>
#       <td>0.909335</td>
#       <td>0.877543</td>
#       <td>0.909335</td>
#       <td>0.883985</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.330200</td>
#       <td>0.287552</td>
#       <td>0.907452</td>
#       <td>0.879362</td>
#       <td>0.907452</td>
#       <td>0.882051</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.288000</td>
#       <td>0.287516</td>
#       <td>0.909605</td>
#       <td>0.882534</td>
#       <td>0.909605</td>
#       <td>0.885405</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.273300</td>
#       <td>0.273177</td>
#       <td>0.907990</td>
#       <td>0.902046</td>
#       <td>0.907990</td>
#       <td>0.903894</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.291200</td>
#       <td>0.277653</td>
#       <td>0.910143</td>
#       <td>0.858597</td>
#       <td>0.910143</td>
#       <td>0.883582</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.326100</td>
#       <td>0.273379</td>
#       <td>0.908259</td>
#       <td>0.856414</td>
#       <td>0.908259</td>
#       <td>0.881574</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.337500</td>
#       <td>0.286990</td>
#       <td>0.909066</td>
#       <td>0.857116</td>
#       <td>0.909066</td>
#       <td>0.882322</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.309300</td>
#       <td>0.290522</td>
#       <td>0.903955</td>
#       <td>0.907600</td>
#       <td>0.903955</td>
#       <td>0.905668</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.278500</td>
#       <td>0.284237</td>
#       <td>0.911219</td>
#       <td>0.896651</td>
#       <td>0.911219</td>
#       <td>0.895025</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.269100</td>
#       <td>0.281861</td>
#       <td>0.906914</td>
#       <td>0.904153</td>
#       <td>0.906914</td>
#       <td>0.905331</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.283700</td>
#       <td>0.262538</td>
#       <td>0.913102</td>
#       <td>0.902028</td>
#       <td>0.913102</td>
#       <td>0.905575</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.264200</td>
#       <td>0.267749</td>
#       <td>0.911757</td>
#       <td>0.891964</td>
#       <td>0.911757</td>
#       <td>0.891557</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.224000</td>
#       <td>0.261588</td>
#       <td>0.912833</td>
#       <td>0.890468</td>
#       <td>0.912833</td>
#       <td>0.888185</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.238300</td>
#       <td>0.282265</td>
#       <td>0.906914</td>
#       <td>0.890828</td>
#       <td>0.906914</td>
#       <td>0.896352</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.245800</td>
#       <td>0.277969</td>
#       <td>0.908259</td>
#       <td>0.884422</td>
#       <td>0.908259</td>
#       <td>0.893526</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.282000</td>
#       <td>0.260330</td>
#       <td>0.914985</td>
#       <td>0.899828</td>
#       <td>0.914985</td>
#       <td>0.904593</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.273100</td>
#       <td>0.252432</td>
#       <td>0.915792</td>
#       <td>0.913730</td>
#       <td>0.915792</td>
#       <td>0.914689</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.276900</td>
#       <td>0.241562</td>
#       <td>0.917945</td>
#       <td>0.905697</td>
#       <td>0.917945</td>
#       <td>0.908875</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.224500</td>
#       <td>0.254507</td>
#       <td>0.917407</td>
#       <td>0.901939</td>
#       <td>0.917407</td>
#       <td>0.903197</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.250400</td>
#       <td>0.251097</td>
#       <td>0.917407</td>
#       <td>0.901766</td>
#       <td>0.917407</td>
#       <td>0.904093</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.243700</td>
#       <td>0.247807</td>
#       <td>0.916599</td>
#       <td>0.901860</td>
#       <td>0.916599</td>
#       <td>0.903017</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.257200</td>
#       <td>0.241959</td>
#       <td>0.917945</td>
#       <td>0.912404</td>
#       <td>0.917945</td>
#       <td>0.914727</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.249300</td>
#       <td>0.248383</td>
#       <td>0.919559</td>
#       <td>0.911081</td>
#       <td>0.919559</td>
#       <td>0.913348</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.280500</td>
#       <td>0.245464</td>
#       <td>0.920366</td>
#       <td>0.913139</td>
#       <td>0.920366</td>
#       <td>0.914105</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.201500</td>
#       <td>0.245364</td>
#       <td>0.917945</td>
#       <td>0.903003</td>
#       <td>0.917945</td>
#       <td>0.902204</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.241100</td>
#       <td>0.234457</td>
#       <td>0.921442</td>
#       <td>0.914684</td>
#       <td>0.921442</td>
#       <td>0.916809</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.245800</td>
#       <td>0.237174</td>
#       <td>0.921711</td>
#       <td>0.910570</td>
#       <td>0.921711</td>
#       <td>0.910458</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.252300</td>
#       <td>0.241984</td>
#       <td>0.921442</td>
#       <td>0.910719</td>
#       <td>0.921442</td>
#       <td>0.908589</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.245000</td>
#       <td>0.238835</td>
#       <td>0.921173</td>
#       <td>0.909765</td>
#       <td>0.921173</td>
#       <td>0.909490</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.197200</td>
#       <td>0.238724</td>
#       <td>0.922518</td>
#       <td>0.913270</td>
#       <td>0.922518</td>
#       <td>0.915055</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.230700</td>
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-50
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-50\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-50\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-100
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-100\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-150
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-150\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-150\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-200
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-200\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-200\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-250
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-250\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-250\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-300
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-300\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-300\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-350
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-350\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-350\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-400
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-400\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-400\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-450
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-450\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-450\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-500
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-500\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-500\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-550
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-550\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-550\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-600
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-600\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-600\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-650
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-650\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-650\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-700
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-700\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-700\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-750
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-750\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-750\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-800
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-800\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-800\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-850
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-850\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-850\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-900
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-900\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-900\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-950
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-950\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-950\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1000
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1000\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1050
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1050\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1050\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1100
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1100\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1150
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1150\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1150\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1200
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1200\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1200\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1250
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1250\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1250\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1300
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1300\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1300\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1350
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1350\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1350\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1400
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1400\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1400\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1450
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1450\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1450\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1500
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1500\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1500\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1550
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1550\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1550\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1600
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1600\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1600\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1650
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1650\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1650\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1700
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1700\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1700\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1750
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1750\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1750\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1800
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1800\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1800\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1850
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1850\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1850\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1900
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1900\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1900\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-1950
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1950\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-1950\pytorch_model.bin
# wandb: Network error resolved after 0:49:44.722740, resuming normal operation.
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-2000
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-2000\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-2000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-2050
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-2050\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-2050\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-2100
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-2100\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-2100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bertweet Training\output\checkpoint-2150
# Configuration saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-2150\config.json
# Model weights saved in D:\COS 802\Project\Bertweet Training\output\checkpoint-2150\pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from D:\COS 802\Project\Bertweet Training\output\checkpoint-1850 (score: 0.2344571053981781).
# TrainOutput(global_step=2170, training_loss=0.2929399650767102, metrics={'train_runtime': 29135.085, 'train_samples_per_second': 1.191, 'train_steps_per_second': 0.074, 'total_flos': 1212443073479232.0, 'train_loss': 0.2929399650767102, 'epoch': 2.0})

# %%
# ----- 3. Predict -----#
# Load test data

X_test = list(df_test['text'])
y_test = list(df_test['label'])

X_test_tokenized = tokenizer(X_test, padding=True, truncation=True, max_length=512)

# %%
# Create torch dataset
test_dataset = Dataset(X_test_tokenized)

# %%
# Load trained model
model_path = "D:\COS 802\Project\Bertweet Training\output\checkpoint-1850"
model = AutoModelForSequenceClassification.from_pretrained(model_path, num_labels=3)
# Out:
# loading configuration file D:\COS 802\Project\Bertweet Training\output\checkpoint-1850\config.json
# Model config RobertaConfig {
#   "_name_or_path": "vinai/bertweet-base",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "tokenizer_class": "BertweetTokenizer",
#   "torch_dtype": "float32",
#   "transformers_version": "4.10.3",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 64001
# }
#
# loading weights file D:\COS 802\Project\Bertweet Training\output\checkpoint-1850\pytorch_model.bin
# All model checkpoint weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the model checkpoint at D:\COS 802\Project\Bertweet Training\output\checkpoint-1850.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.

# %%
# Define test trainer
test_trainer = Trainer(model)
# Out:
# No `TrainingArguments` passed, using `output_dir=tmp_trainer`.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
# Make prediction
raw_pred, _, _ = test_trainer.predict(test_dataset)

# Preprocess raw predictions
y_pred = np.argmax(raw_pred, axis=1)
# Out:
# ***** Running Prediction *****
#   Num examples = 3718
#   Batch size = 8
#     <div>
#
#       <progress value='465' max='465' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [465/465 04:12]
#     </div>

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[  78,  113,   22],
#        [  65, 2776,   64],
#        [  14,   28,  558]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.37      0.42       213
#            1       0.95      0.96      0.95      2905
#            2       0.87      0.93      0.90       600
#
#     accuracy                           0.92      3718
#    macro avg       0.77      0.75      0.76      3718
# weighted avg       0.91      0.92      0.91      3718
