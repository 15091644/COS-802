# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, matthews_corrcoef
import torch
from transformers import TrainingArguments, Trainer
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification
from transformers import EarlyStoppingCallback

# %% [markdown]
# ### Load Data Set

# %%
df_train = pd.read_csv('training.csv')
df_val = pd.read_csv('validation.csv')
df_test = pd.read_csv('testing.csv')

df_train.head()
# Out:
#    Unnamed: 0                                               text  label
# 0       19429  retweet mentionhere: people be like from bae t...      1
# 1       10662  i like being teased, do not give me the pussy ...      1
# 2       19558         retweet mentionhere: you are jealous bitch      1
# 3        2909  mentionhere cuz people at work are bitches the...      1
# 4       24378  quote this with your best racist comment i nee...      1

# %%
# Define pretrained tokenizer and model

model_name = "distilbert-base-uncased"

tokenizer = DistilBertTokenizer.from_pretrained(model_name)

model = DistilBertForSequenceClassification.from_pretrained(model_name, num_labels=3)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.bias', 'vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'classifier.bias', 'classifier.weight', 'pre_classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# ----- 1. Preprocess data -----#
# Preprocess data

X_train = list(df_train["text"])
y_train = list(df_train["label"])

X_val = list(df_val["text"])
y_val = list(df_val["label"])

X_train_tokenized = tokenizer(X_train, padding=True, truncation=True, max_length=512)
X_val_tokenized = tokenizer(X_val, padding=True, truncation=True, max_length=512)

# %%
# Create torch dataset
class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels=None):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        if self.labels:
            item["labels"] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.encodings["input_ids"])

# %%
train_dataset = Dataset(X_train_tokenized, y_train)
val_dataset = Dataset(X_val_tokenized, y_val)

# %%
# ----- 2. Fine-tune pretrained model -----#
# Define Trainer parameters
def compute_metrics(p):
    pred, labels = p
    pred = np.argmax(pred, axis=1)

    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    recall = recall_score(y_true=labels, y_pred=pred, average='weighted')
    precision = precision_score(y_true=labels, y_pred=pred, average = 'weighted')
    f1 = f1_score(y_true=labels, y_pred=pred, average = 'weighted')

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1, }

# %%
# Define Trainer

args = TrainingArguments(
    output_dir="D:\COS 802\Project\Distilbert Training\output",
    evaluation_strategy="steps",
    eval_steps=50,
    logging_steps = 50,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=2,
    seed=0,
    load_best_model_at_end=True,
    report_to="wandb",  # enable logging to W&B
    run_name="distilbert"  # name of the W&B run (optional)
)
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
    #callbacks=[EarlyStoppingCallback(early_stopping_patience=3)],
)

# %%
# Train pre-trained model
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 17348
#   Num Epochs = 2
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2170
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: jesseparvess-elucidate (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">distilbert</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jesseparvess-elucidate/huggingface" target="_blank">https://wandb.ai/jesseparvess-elucidate/huggingface</a><br/>
#                 Run page: <a href="https://wandb.ai/jesseparvess-elucidate/huggingface/runs/38inyjvs" target="_blank">https://wandb.ai/jesseparvess-elucidate/huggingface/runs/38inyjvs</a><br/>
#                 Run data is saved locally in <code>C:\Users\jesse\Documents\Masters\COS 802\Project\Fitted Transformers\distilBERT\wandb\run-20211108_190408-38inyjvs</code><br/><br/>
#     <div>
#
#       <progress value='2170' max='2170' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2170/2170 15:00:38, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.555300</td>
#       <td>0.421451</td>
#       <td>0.853107</td>
#       <td>0.804625</td>
#       <td>0.853107</td>
#       <td>0.817872</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.356700</td>
#       <td>0.318777</td>
#       <td>0.894001</td>
#       <td>0.842734</td>
#       <td>0.894001</td>
#       <td>0.867598</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.328300</td>
#       <td>0.299139</td>
#       <td>0.888620</td>
#       <td>0.876462</td>
#       <td>0.888620</td>
#       <td>0.879999</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.294000</td>
#       <td>0.309633</td>
#       <td>0.898036</td>
#       <td>0.898155</td>
#       <td>0.898036</td>
#       <td>0.894370</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.347900</td>
#       <td>0.286257</td>
#       <td>0.905031</td>
#       <td>0.910265</td>
#       <td>0.905031</td>
#       <td>0.880746</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.329400</td>
#       <td>0.294542</td>
#       <td>0.909066</td>
#       <td>0.891386</td>
#       <td>0.909066</td>
#       <td>0.888152</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.282600</td>
#       <td>0.288855</td>
#       <td>0.905300</td>
#       <td>0.878820</td>
#       <td>0.905300</td>
#       <td>0.885826</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.294600</td>
#       <td>0.287163</td>
#       <td>0.904493</td>
#       <td>0.883737</td>
#       <td>0.904493</td>
#       <td>0.886203</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.334000</td>
#       <td>0.286899</td>
#       <td>0.903148</td>
#       <td>0.884738</td>
#       <td>0.903148</td>
#       <td>0.888715</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.303000</td>
#       <td>0.303929</td>
#       <td>0.892117</td>
#       <td>0.865296</td>
#       <td>0.892117</td>
#       <td>0.869444</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.275800</td>
#       <td>0.258857</td>
#       <td>0.910143</td>
#       <td>0.891176</td>
#       <td>0.910143</td>
#       <td>0.889253</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.289600</td>
#       <td>0.266974</td>
#       <td>0.909066</td>
#       <td>0.899574</td>
#       <td>0.909066</td>
#       <td>0.903247</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.300900</td>
#       <td>0.259261</td>
#       <td>0.909066</td>
#       <td>0.889682</td>
#       <td>0.909066</td>
#       <td>0.889727</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.265900</td>
#       <td>0.258740</td>
#       <td>0.910681</td>
#       <td>0.905156</td>
#       <td>0.910681</td>
#       <td>0.907028</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.241400</td>
#       <td>0.259461</td>
#       <td>0.910143</td>
#       <td>0.904591</td>
#       <td>0.910143</td>
#       <td>0.906231</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.291100</td>
#       <td>0.268270</td>
#       <td>0.907183</td>
#       <td>0.898211</td>
#       <td>0.907183</td>
#       <td>0.881740</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.281700</td>
#       <td>0.251948</td>
#       <td>0.911488</td>
#       <td>0.904207</td>
#       <td>0.911488</td>
#       <td>0.905437</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.317200</td>
#       <td>0.263708</td>
#       <td>0.911757</td>
#       <td>0.901176</td>
#       <td>0.911757</td>
#       <td>0.887289</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.284100</td>
#       <td>0.257522</td>
#       <td>0.910681</td>
#       <td>0.907882</td>
#       <td>0.910681</td>
#       <td>0.909070</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.241800</td>
#       <td>0.276516</td>
#       <td>0.910950</td>
#       <td>0.895137</td>
#       <td>0.910950</td>
#       <td>0.893542</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.256900</td>
#       <td>0.255766</td>
#       <td>0.912564</td>
#       <td>0.889667</td>
#       <td>0.912564</td>
#       <td>0.894557</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.250300</td>
#       <td>0.261319</td>
#       <td>0.910681</td>
#       <td>0.886981</td>
#       <td>0.910681</td>
#       <td>0.890268</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.224700</td>
#       <td>0.260373</td>
#       <td>0.912295</td>
#       <td>0.890910</td>
#       <td>0.912295</td>
#       <td>0.892000</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.172500</td>
#       <td>0.268253</td>
#       <td>0.912833</td>
#       <td>0.890775</td>
#       <td>0.912833</td>
#       <td>0.893769</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.219000</td>
#       <td>0.283708</td>
#       <td>0.910950</td>
#       <td>0.887094</td>
#       <td>0.910950</td>
#       <td>0.891319</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.219200</td>
#       <td>0.283520</td>
#       <td>0.912833</td>
#       <td>0.891769</td>
#       <td>0.912833</td>
#       <td>0.895501</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.232400</td>
#       <td>0.267773</td>
#       <td>0.916330</td>
#       <td>0.907755</td>
#       <td>0.916330</td>
#       <td>0.910803</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.252500</td>
#       <td>0.262301</td>
#       <td>0.913371</td>
#       <td>0.906689</td>
#       <td>0.913371</td>
#       <td>0.909049</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.219400</td>
#       <td>0.260580</td>
#       <td>0.915254</td>
#       <td>0.901002</td>
#       <td>0.915254</td>
#       <td>0.902669</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.186700</td>
#       <td>0.270027</td>
#       <td>0.913371</td>
#       <td>0.907562</td>
#       <td>0.913371</td>
#       <td>0.909675</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.226100</td>
#       <td>0.270486</td>
#       <td>0.914716</td>
#       <td>0.907711</td>
#       <td>0.914716</td>
#       <td>0.909826</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.235200</td>
#       <td>0.259897</td>
#       <td>0.915792</td>
#       <td>0.901724</td>
#       <td>0.915792</td>
#       <td>0.900527</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.226100</td>
#       <td>0.252535</td>
#       <td>0.914447</td>
#       <td>0.904157</td>
#       <td>0.914447</td>
#       <td>0.907583</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.203200</td>
#       <td>0.275347</td>
#       <td>0.910143</td>
#       <td>0.901340</td>
#       <td>0.910143</td>
#       <td>0.903812</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.235300</td>
#       <td>0.262303</td>
#       <td>0.918214</td>
#       <td>0.914394</td>
#       <td>0.918214</td>
#       <td>0.915659</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.187000</td>
#       <td>0.266303</td>
#       <td>0.915792</td>
#       <td>0.903231</td>
#       <td>0.915792</td>
#       <td>0.904387</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.208100</td>
#       <td>0.255240</td>
#       <td>0.918752</td>
#       <td>0.910169</td>
#       <td>0.918752</td>
#       <td>0.912386</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.213300</td>
#       <td>0.261282</td>
#       <td>0.919828</td>
#       <td>0.910989</td>
#       <td>0.919828</td>
#       <td>0.904709</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.235400</td>
#       <td>0.259986</td>
#       <td>0.919021</td>
#       <td>0.910481</td>
#       <td>0.919021</td>
#       <td>0.901530</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.223200</td>
#       <td>0.256347</td>
#       <td>0.916599</td>
#       <td>0.905131</td>
#       <td>0.916599</td>
#       <td>0.899649</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.180600</td>
#       <td>0.259055</td>
#       <td>0.918752</td>
#       <td>0.908686</td>
#       <td>0.918752</td>
#       <td>0.904637</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.189600</td>
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-50
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-50\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-50\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-100
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-100\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-150
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-150\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-150\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-200
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-200\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-200\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-250
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-250\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-250\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-300
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-300\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-300\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-350
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-350\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-350\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-400
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-400\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-400\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-450
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-450\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-450\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-500
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-500\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-500\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-550
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-550\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-550\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-600
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-600\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-600\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# wandb: Network error resolved after 8:23:24.977606, resuming normal operation.
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-650
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-650\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-650\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-700
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-700\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-700\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-750
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-750\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-750\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-800
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-800\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-800\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-850
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-850\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-850\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-900
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-900\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-900\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-950
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-950\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-950\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1000
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1000\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# wandb: Network error resolved after 0:09:30.928421, resuming normal operation.
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1050
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1050\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1050\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1100
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1100\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1150
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1150\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1150\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1200
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1200\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1200\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1250
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1250\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1250\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1300
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1300\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1300\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1350
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1350\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1350\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1400
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1400\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1400\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1450
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1450\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1450\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1500
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1500\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1500\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1550
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1550\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1550\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1600
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1600\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1600\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1650
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1650\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1650\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1700
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1700\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1700\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1750
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1750\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1750\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1800
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1800\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1800\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1850
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1850\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1850\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1900
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1900\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1900\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-1950
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1950\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-1950\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-2000
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-2000\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-2000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-2050
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-2050\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-2050\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# wandb: Network error resolved after 0:04:54.700902, resuming normal operation.
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-2100
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-2100\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-2100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Distilbert Training\output\checkpoint-2150
# Configuration saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-2150\config.json
# Model weights saved in D:\COS 802\Project\Distilbert Training\output\checkpoint-2150\pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from D:\COS 802\Project\Distilbert Training\output\checkpoint-850 (score: 0.2519483268260956).
# TrainOutput(global_step=2170, training_loss=0.2608224095287411, metrics={'train_runtime': 54049.1982, 'train_samples_per_second': 0.642, 'train_steps_per_second': 0.04, 'total_flos': 619405834308048.0, 'train_loss': 0.2608224095287411, 'epoch': 2.0})

# %%
# ----- 3. Predict -----#
# Load test data

X_test = list(df_test['text'])
y_test = list(df_test['label'])

X_test_tokenized = tokenizer(X_test, padding=True, truncation=True, max_length=512)

# %%
# Create torch dataset
test_dataset = Dataset(X_test_tokenized)

# %%
# Load trained model
model_path = "D:\COS 802\Project\Distilbert Training\output\checkpoint-1750"
model = DistilBertForSequenceClassification.from_pretrained(model_path, num_labels=3)
# Out:
# loading configuration file D:\COS 802\Project\Distilbert Training\output\checkpoint-1750\config.json
# Model config DistilBertConfig {
#   "_name_or_path": "distilbert-base-uncased",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForSequenceClassification"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "problem_type": "single_label_classification",
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.10.3",
#   "vocab_size": 30522
# }
#
# loading weights file D:\COS 802\Project\Distilbert Training\output\checkpoint-1750\pytorch_model.bin
# All model checkpoint weights were used when initializing DistilBertForSequenceClassification.
#
# All the weights of DistilBertForSequenceClassification were initialized from the model checkpoint at D:\COS 802\Project\Distilbert Training\output\checkpoint-1750.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use DistilBertForSequenceClassification for predictions without further training.

# %%
# Define test trainer
test_trainer = Trainer(model)
# Out:
# No `TrainingArguments` passed, using `output_dir=tmp_trainer`.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
# Make prediction
raw_pred, _, _ = test_trainer.predict(test_dataset)

# Preprocess raw predictions
y_pred = np.argmax(raw_pred, axis=1)
# Out:
# ***** Running Prediction *****
#   Num examples = 3718
#   Batch size = 8
#     <div>
#
#       <progress value='465' max='465' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [465/465 02:41]
#     </div>

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[  90,  104,   19],
#        [  75, 2754,   76],
#        [  15,   28,  557]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.42      0.46       213
#            1       0.95      0.95      0.95      2905
#            2       0.85      0.93      0.89       600
#
#     accuracy                           0.91      3718
#    macro avg       0.77      0.77      0.77      3718
# weighted avg       0.91      0.91      0.91      3718
