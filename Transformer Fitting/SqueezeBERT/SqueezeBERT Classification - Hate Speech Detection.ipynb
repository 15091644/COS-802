# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, matthews_corrcoef
import torch
from transformers import TrainingArguments, Trainer
from transformers import SqueezeBertTokenizer, SqueezeBertForSequenceClassification
from transformers import EarlyStoppingCallback

# %% [markdown]
# ### Load Data Set

# %%
df_train = pd.read_csv('training.csv')
df_val = pd.read_csv('validation.csv')
df_test = pd.read_csv('testing.csv')

df_train.head()
# Out:
#    Unnamed: 0                                               text  label
# 0       19429  retweet mentionhere: people be like from bae t...      1
# 1       10662  i like being teased, do not give me the pussy ...      1
# 2       19558         retweet mentionhere: you are jealous bitch      1
# 3        2909  mentionhere cuz people at work are bitches the...      1
# 4       24378  quote this with your best racist comment i nee...      1

# %%
# Define pretrained tokenizer and model

model_name = 'squeezebert/squeezebert-uncased'

tokenizer = SqueezeBertTokenizer.from_pretrained(model_name)

model = SqueezeBertForSequenceClassification.from_pretrained(model_name, num_labels=3)
# Out:
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/500 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/103M [00:00<?, ?B/s]
# Some weights of the model checkpoint at squeezebert/squeezebert-uncased were not used when initializing SqueezeBertForSequenceClassification: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing SqueezeBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing SqueezeBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of SqueezeBertForSequenceClassification were not initialized from the model checkpoint at squeezebert/squeezebert-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# ----- 1. Preprocess data -----#
# Preprocess data

X_train = list(df_train["text"])
y_train = list(df_train["label"])

X_val = list(df_val["text"])
y_val = list(df_val["label"])

X_train_tokenized = tokenizer(X_train, padding=True, truncation=True, max_length=512)
X_val_tokenized = tokenizer(X_val, padding=True, truncation=True, max_length=512)

# %%
# Create torch dataset
class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels=None):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        if self.labels:
            item["labels"] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.encodings["input_ids"])

# %%
train_dataset = Dataset(X_train_tokenized, y_train)
val_dataset = Dataset(X_val_tokenized, y_val)

# %%
# ----- 2. Fine-tune pretrained model -----#
# Define Trainer parameters
def compute_metrics(p):
    pred, labels = p
    pred = np.argmax(pred, axis=1)

    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    recall = recall_score(y_true=labels, y_pred=pred, average='weighted')
    precision = precision_score(y_true=labels, y_pred=pred, average = 'weighted')
    f1 = f1_score(y_true=labels, y_pred=pred, average = 'weighted')

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1, }

# %%
# Define Trainer

args = TrainingArguments(
    output_dir="D:\COS 802\Project\Squeezebert Training\output",
    evaluation_strategy="steps",
    eval_steps=50,
    logging_steps = 50,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=2,
    seed=0,
    load_best_model_at_end=True,
    report_to="wandb",  # enable logging to W&B
    run_name="squeezebert"  # name of the W&B run (optional)
)
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
    #callbacks=[EarlyStoppingCallback(early_stopping_patience=3)],
)

# %%
# Train pre-trained model
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 17348
#   Num Epochs = 2
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2170
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: jesseparvess-elucidate (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">squeezebert</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jesseparvess-elucidate/huggingface" target="_blank">https://wandb.ai/jesseparvess-elucidate/huggingface</a><br/>
#                 Run page: <a href="https://wandb.ai/jesseparvess-elucidate/huggingface/runs/2m4gulqq" target="_blank">https://wandb.ai/jesseparvess-elucidate/huggingface/runs/2m4gulqq</a><br/>
#                 Run data is saved locally in <code>C:\Users\jesse\Documents\Masters\COS 802\Project\Fitted Transformers\SqueezeBERT\wandb\run-20211110_135736-2m4gulqq</code><br/><br/>
#     <div>
#
#       <progress value='2170' max='2170' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2170/2170 18:59:31, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.612800</td>
#       <td>0.426848</td>
#       <td>0.865752</td>
#       <td>0.813399</td>
#       <td>0.865752</td>
#       <td>0.836852</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.402600</td>
#       <td>0.402064</td>
#       <td>0.883777</td>
#       <td>0.831944</td>
#       <td>0.883777</td>
#       <td>0.856238</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.369600</td>
#       <td>0.345256</td>
#       <td>0.891310</td>
#       <td>0.874826</td>
#       <td>0.891310</td>
#       <td>0.868341</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.354000</td>
#       <td>0.339525</td>
#       <td>0.885930</td>
#       <td>0.880625</td>
#       <td>0.885930</td>
#       <td>0.875107</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.376100</td>
#       <td>0.347792</td>
#       <td>0.893462</td>
#       <td>0.841586</td>
#       <td>0.893462</td>
#       <td>0.866240</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.348200</td>
#       <td>0.326530</td>
#       <td>0.902072</td>
#       <td>0.851909</td>
#       <td>0.902072</td>
#       <td>0.876087</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.322700</td>
#       <td>0.297122</td>
#       <td>0.902610</td>
#       <td>0.853196</td>
#       <td>0.902610</td>
#       <td>0.876822</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.295700</td>
#       <td>0.293415</td>
#       <td>0.904762</td>
#       <td>0.893279</td>
#       <td>0.904762</td>
#       <td>0.879759</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.329100</td>
#       <td>0.293061</td>
#       <td>0.905569</td>
#       <td>0.891782</td>
#       <td>0.905569</td>
#       <td>0.890381</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.295700</td>
#       <td>0.324684</td>
#       <td>0.894270</td>
#       <td>0.842544</td>
#       <td>0.894270</td>
#       <td>0.866784</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.280100</td>
#       <td>0.283431</td>
#       <td>0.908259</td>
#       <td>0.888239</td>
#       <td>0.908259</td>
#       <td>0.884751</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.331100</td>
#       <td>0.286037</td>
#       <td>0.908259</td>
#       <td>0.898316</td>
#       <td>0.908259</td>
#       <td>0.899763</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.319800</td>
#       <td>0.278591</td>
#       <td>0.910950</td>
#       <td>0.900824</td>
#       <td>0.910950</td>
#       <td>0.900142</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.279200</td>
#       <td>0.290727</td>
#       <td>0.908259</td>
#       <td>0.893034</td>
#       <td>0.908259</td>
#       <td>0.889773</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.252400</td>
#       <td>0.261360</td>
#       <td>0.908797</td>
#       <td>0.900847</td>
#       <td>0.908797</td>
#       <td>0.902569</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.306900</td>
#       <td>0.270359</td>
#       <td>0.912295</td>
#       <td>0.897962</td>
#       <td>0.912295</td>
#       <td>0.895498</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.272700</td>
#       <td>0.263378</td>
#       <td>0.909335</td>
#       <td>0.909612</td>
#       <td>0.909335</td>
#       <td>0.908847</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.362600</td>
#       <td>0.271147</td>
#       <td>0.913371</td>
#       <td>0.918796</td>
#       <td>0.913371</td>
#       <td>0.889474</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.285500</td>
#       <td>0.267745</td>
#       <td>0.907990</td>
#       <td>0.904634</td>
#       <td>0.907990</td>
#       <td>0.905967</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.260400</td>
#       <td>0.268331</td>
#       <td>0.912295</td>
#       <td>0.907353</td>
#       <td>0.912295</td>
#       <td>0.907985</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.268400</td>
#       <td>0.269725</td>
#       <td>0.910143</td>
#       <td>0.907574</td>
#       <td>0.910143</td>
#       <td>0.908599</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.251300</td>
#       <td>0.277846</td>
#       <td>0.905838</td>
#       <td>0.896648</td>
#       <td>0.905838</td>
#       <td>0.900104</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.227200</td>
#       <td>0.273533</td>
#       <td>0.907990</td>
#       <td>0.889974</td>
#       <td>0.907990</td>
#       <td>0.891452</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.213000</td>
#       <td>0.266923</td>
#       <td>0.913909</td>
#       <td>0.900578</td>
#       <td>0.913909</td>
#       <td>0.899146</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.238000</td>
#       <td>0.275840</td>
#       <td>0.908259</td>
#       <td>0.888449</td>
#       <td>0.908259</td>
#       <td>0.893278</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.238900</td>
#       <td>0.269749</td>
#       <td>0.913102</td>
#       <td>0.904634</td>
#       <td>0.913102</td>
#       <td>0.907675</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.241100</td>
#       <td>0.266996</td>
#       <td>0.907990</td>
#       <td>0.907857</td>
#       <td>0.907990</td>
#       <td>0.907904</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.274400</td>
#       <td>0.262307</td>
#       <td>0.912833</td>
#       <td>0.902927</td>
#       <td>0.912833</td>
#       <td>0.904851</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.230800</td>
#       <td>0.258215</td>
#       <td>0.908528</td>
#       <td>0.899532</td>
#       <td>0.908528</td>
#       <td>0.902942</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.197000</td>
#       <td>0.268889</td>
#       <td>0.910412</td>
#       <td>0.907113</td>
#       <td>0.910412</td>
#       <td>0.908449</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.248200</td>
#       <td>0.268419</td>
#       <td>0.912295</td>
#       <td>0.910448</td>
#       <td>0.912295</td>
#       <td>0.911079</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.271300</td>
#       <td>0.265688</td>
#       <td>0.914447</td>
#       <td>0.904353</td>
#       <td>0.914447</td>
#       <td>0.905139</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.254900</td>
#       <td>0.255736</td>
#       <td>0.907183</td>
#       <td>0.904068</td>
#       <td>0.907183</td>
#       <td>0.905494</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.237900</td>
#       <td>0.258335</td>
#       <td>0.909335</td>
#       <td>0.903296</td>
#       <td>0.909335</td>
#       <td>0.905644</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.265700</td>
#       <td>0.253957</td>
#       <td>0.912564</td>
#       <td>0.909177</td>
#       <td>0.912564</td>
#       <td>0.910560</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.216800</td>
#       <td>0.254569</td>
#       <td>0.914985</td>
#       <td>0.906391</td>
#       <td>0.914985</td>
#       <td>0.907875</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.242200</td>
#       <td>0.247057</td>
#       <td>0.914447</td>
#       <td>0.910126</td>
#       <td>0.914447</td>
#       <td>0.911641</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.227200</td>
#       <td>0.252170</td>
#       <td>0.916599</td>
#       <td>0.907300</td>
#       <td>0.916599</td>
#       <td>0.906172</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.249200</td>
#       <td>0.251767</td>
#       <td>0.918214</td>
#       <td>0.909730</td>
#       <td>0.918214</td>
#       <td>0.908900</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.240300</td>
#       <td>0.248749</td>
#       <td>0.916330</td>
#       <td>0.907186</td>
#       <td>0.916330</td>
#       <td>0.907754</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.196400</td>
#       <td>0.250730</td>
#       <td>0.917676</td>
#       <td>0.910178</td>
#       <td>0.917676</td>
#       <td>0.911575</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.210700</td>
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-50
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-50\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-50\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# wandb: Network error resolved after 0:02:39.692465, resuming normal operation.
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-100
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-100\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-150
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-150\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-150\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-200
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-200\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-200\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-250
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-250\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-250\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-300
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-300\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-300\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-350
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-350\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-350\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-400
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-400\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-400\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-450
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-450\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-450\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-500
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-500\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-500\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-550
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-550\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-550\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-600
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-600\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-600\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-650
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-650\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-650\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-700
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-700\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-700\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-750
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-750\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-750\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-800
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-800\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-800\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-850
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-850\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-850\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-900
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-900\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-900\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-950
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-950\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-950\pytorch_model.bin
# wandb: Network error resolved after 0:27:02.118406, resuming normal operation.
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# wandb: Network error resolved after 0:00:59.013431, resuming normal operation.
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1000
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1000\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1050
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1050\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1050\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# wandb: Network error resolved after 0:54:18.063849, resuming normal operation.
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1100
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1100\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1150
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1150\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1150\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1200
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1200\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1200\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1250
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1250\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1250\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1300
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1300\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1300\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1350
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1350\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1350\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1400
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1400\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1400\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1450
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1450\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1450\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1500
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1500\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1500\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1550
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1550\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1550\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1600
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1600\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1600\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1650
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1650\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1650\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1700
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1700\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1700\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1750
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1750\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1750\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1800
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1800\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1800\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1850
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1850\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1850\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1900
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1900\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1900\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-1950
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1950\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-1950\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-2000
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-2000\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-2000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-2050
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-2050\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-2050\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-2100
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-2100\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-2100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Squeezebert Training\output\checkpoint-2150
# Configuration saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-2150\config.json
# Model weights saved in D:\COS 802\Project\Squeezebert Training\output\checkpoint-2150\pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from D:\COS 802\Project\Squeezebert Training\output\checkpoint-1850 (score: 0.24705691635608673).
# TrainOutput(global_step=2170, training_loss=0.28176188073399977, metrics={'train_runtime': 68384.5318, 'train_samples_per_second': 0.507, 'train_steps_per_second': 0.032, 'total_flos': 391513748482512.0, 'train_loss': 0.28176188073399977, 'epoch': 2.0})

# %%
# ----- 3. Predict -----#
# Load test data

X_test = list(df_test['text'])
y_test = list(df_test['label'])

X_test_tokenized = tokenizer(X_test, padding=True, truncation=True, max_length=512)

# %%
# Create torch dataset
test_dataset = Dataset(X_test_tokenized)

# %%
# Load trained model
model_path = "D:\COS 802\Project\Squeezebert Training\output\checkpoint-1850"
model = SqueezeBertForSequenceClassification.from_pretrained(model_path, num_labels=3)
# Out:
# loading configuration file D:\COS 802\Project\Squeezebert Training\output\checkpoint-1850\config.json
# Model config SqueezeBertConfig {
#   "_name_or_path": "squeezebert/squeezebert-uncased",
#   "architectures": [
#     "SqueezeBertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "embedding_size": 768,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "intermediate_groups": 4,
#   "intermediate_size": 3072,
#   "k_groups": 4,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "squeezebert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_groups": 4,
#   "pad_token_id": 0,
#   "post_attention_groups": 1,
#   "problem_type": "single_label_classification",
#   "q_groups": 4,
#   "torch_dtype": "float32",
#   "transformers_version": "4.10.3",
#   "type_vocab_size": 2,
#   "v_groups": 4,
#   "vocab_size": 30528
# }
#
# loading weights file D:\COS 802\Project\Squeezebert Training\output\checkpoint-1850\pytorch_model.bin
# All model checkpoint weights were used when initializing SqueezeBertForSequenceClassification.
#
# All the weights of SqueezeBertForSequenceClassification were initialized from the model checkpoint at D:\COS 802\Project\Squeezebert Training\output\checkpoint-1850.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use SqueezeBertForSequenceClassification for predictions without further training.

# %%
# Define test trainer
test_trainer = Trainer(model)
# Out:
# No `TrainingArguments` passed, using `output_dir=tmp_trainer`.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
# Make prediction
raw_pred, _, _ = test_trainer.predict(test_dataset)

# Preprocess raw predictions
y_pred = np.argmax(raw_pred, axis=1)
# Out:
# ***** Running Prediction *****
#   Num examples = 3718
#   Batch size = 8
#     <div>
#
#       <progress value='465' max='465' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [465/465 07:18]
#     </div>

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[  86,  105,   22],
#        [  84, 2748,   73],
#        [   8,   47,  545]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.40      0.44       213
#            1       0.95      0.95      0.95      2905
#            2       0.85      0.91      0.88       600
#
#     accuracy                           0.91      3718
#    macro avg       0.76      0.75      0.76      3718
# weighted avg       0.91      0.91      0.91      3718
