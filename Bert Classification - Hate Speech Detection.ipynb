# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, matthews_corrcoef
import torch
from transformers import TrainingArguments, Trainer
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import EarlyStoppingCallback

# %% [markdown]
# ### Load Data Set

# %%
df_train = pd.read_csv('training.csv')
df_val = pd.read_csv('validation.csv')
df_test = pd.read_csv('testing.csv')

df_train.head()
# Out:
#    Unnamed: 0                                               text  label
# 0       19429  retweet mentionhere: people be like from bae t...      1
# 1       10662  i like being teased, do not give me the pussy ...      1
# 2       19558         retweet mentionhere: you are jealous bitch      1
# 3        2909  mentionhere cuz people at work are bitches the...      1
# 4       24378  quote this with your best racist comment i nee...      1

# %%
# Define pretrained tokenizer and model
model_name = "bert-base-uncased"

tokenizer = BertTokenizer.from_pretrained(model_name)

model = BertForSequenceClassification.from_pretrained(model_name, num_labels=3)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# ----- 1. Preprocess data -----#
# Preprocess data

X_train = list(df_train["text"])
y_train = list(df_train["label"])

X_val = list(df_val["text"])
y_val = list(df_val["label"])

X_train_tokenized = tokenizer(X_train, padding=True, truncation=True, max_length=512)
X_val_tokenized = tokenizer(X_val, padding=True, truncation=True, max_length=512)

# %%
# Create torch dataset
class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels=None):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        if self.labels:
            item["labels"] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.encodings["input_ids"])

# %%
train_dataset = Dataset(X_train_tokenized, y_train)
val_dataset = Dataset(X_val_tokenized, y_val)

# %%
# ----- 2. Fine-tune pretrained model -----#
# Define Trainer parameters
def compute_metrics(p):
    pred, labels = p
    pred = np.argmax(pred, axis=1)

    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    recall = recall_score(y_true=labels, y_pred=pred, average='weighted')
    precision = precision_score(y_true=labels, y_pred=pred, average = 'weighted')
    f1 = f1_score(y_true=labels, y_pred=pred, average = 'weighted')

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1, }

# %%
# Define Trainer

args = TrainingArguments(
    output_dir="D:\COS 802\Project\Bert Training\output",
    evaluation_strategy="steps",
    eval_steps=50,
    logging_steps = 50,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=2,
    seed=0,
    load_best_model_at_end=True,
    report_to="wandb",  # enable logging to W&B
    run_name="bert-base"  # name of the W&B run (optional)
)
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
    #callbacks=[EarlyStoppingCallback(early_stopping_patience=3)],
)

# %%
# Train pre-trained model
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 17348
#   Num Epochs = 2
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2170
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: jesseparvess-elucidate (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">bert-base</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jesseparvess-elucidate/huggingface" target="_blank">https://wandb.ai/jesseparvess-elucidate/huggingface</a><br/>
#                 Run page: <a href="https://wandb.ai/jesseparvess-elucidate/huggingface/runs/i30p75yd" target="_blank">https://wandb.ai/jesseparvess-elucidate/huggingface/runs/i30p75yd</a><br/>
#                 Run data is saved locally in <code>C:\Users\jesse\Documents\Masters\COS 802\Project\Fitted Transformers\Bert\wandb\run-20211107_125415-i30p75yd</code><br/><br/>
#     <div>
#
#       <progress value='2170' max='2170' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2170/2170 21:11:00, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.527300</td>
#       <td>0.380925</td>
#       <td>0.871671</td>
#       <td>0.822137</td>
#       <td>0.871671</td>
#       <td>0.846179</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.387600</td>
#       <td>0.322590</td>
#       <td>0.900995</td>
#       <td>0.849653</td>
#       <td>0.900995</td>
#       <td>0.874571</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.302500</td>
#       <td>0.317613</td>
#       <td>0.895346</td>
#       <td>0.881767</td>
#       <td>0.895346</td>
#       <td>0.887557</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.291700</td>
#       <td>0.294432</td>
#       <td>0.904224</td>
#       <td>0.895169</td>
#       <td>0.904224</td>
#       <td>0.896664</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.343100</td>
#       <td>0.301870</td>
#       <td>0.895884</td>
#       <td>0.844265</td>
#       <td>0.895884</td>
#       <td>0.868547</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.338300</td>
#       <td>0.280372</td>
#       <td>0.905838</td>
#       <td>0.902006</td>
#       <td>0.905838</td>
#       <td>0.883229</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.284600</td>
#       <td>0.307633</td>
#       <td>0.900995</td>
#       <td>0.906856</td>
#       <td>0.900995</td>
#       <td>0.875056</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.298800</td>
#       <td>0.294241</td>
#       <td>0.906107</td>
#       <td>0.895597</td>
#       <td>0.906107</td>
#       <td>0.896443</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.332600</td>
#       <td>0.287773</td>
#       <td>0.906107</td>
#       <td>0.888680</td>
#       <td>0.906107</td>
#       <td>0.892000</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.292700</td>
#       <td>0.281477</td>
#       <td>0.900726</td>
#       <td>0.849179</td>
#       <td>0.900726</td>
#       <td>0.873529</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.256400</td>
#       <td>0.258299</td>
#       <td>0.912833</td>
#       <td>0.897271</td>
#       <td>0.912833</td>
#       <td>0.897622</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.284300</td>
#       <td>0.265582</td>
#       <td>0.913640</td>
#       <td>0.902300</td>
#       <td>0.913640</td>
#       <td>0.905187</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.309900</td>
#       <td>0.257188</td>
#       <td>0.912295</td>
#       <td>0.902728</td>
#       <td>0.912295</td>
#       <td>0.905406</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.257000</td>
#       <td>0.267439</td>
#       <td>0.908528</td>
#       <td>0.875323</td>
#       <td>0.908528</td>
#       <td>0.884591</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.253400</td>
#       <td>0.265980</td>
#       <td>0.909335</td>
#       <td>0.908076</td>
#       <td>0.909335</td>
#       <td>0.907893</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.299600</td>
#       <td>0.279558</td>
#       <td>0.903686</td>
#       <td>0.887072</td>
#       <td>0.903686</td>
#       <td>0.880624</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.293000</td>
#       <td>0.263206</td>
#       <td>0.909874</td>
#       <td>0.908080</td>
#       <td>0.909874</td>
#       <td>0.908244</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.313900</td>
#       <td>0.275630</td>
#       <td>0.908528</td>
#       <td>0.856556</td>
#       <td>0.908528</td>
#       <td>0.881759</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.284600</td>
#       <td>0.272653</td>
#       <td>0.909066</td>
#       <td>0.903485</td>
#       <td>0.909066</td>
#       <td>0.905852</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.262500</td>
#       <td>0.269224</td>
#       <td>0.911757</td>
#       <td>0.894682</td>
#       <td>0.911757</td>
#       <td>0.895398</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.253900</td>
#       <td>0.276426</td>
#       <td>0.911488</td>
#       <td>0.908201</td>
#       <td>0.911488</td>
#       <td>0.909670</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.260300</td>
#       <td>0.273648</td>
#       <td>0.907990</td>
#       <td>0.889327</td>
#       <td>0.907990</td>
#       <td>0.892476</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.249800</td>
#       <td>0.256879</td>
#       <td>0.912564</td>
#       <td>0.893773</td>
#       <td>0.912564</td>
#       <td>0.891650</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.170500</td>
#       <td>0.284940</td>
#       <td>0.914178</td>
#       <td>0.899842</td>
#       <td>0.914178</td>
#       <td>0.894819</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.212100</td>
#       <td>0.295445</td>
#       <td>0.906107</td>
#       <td>0.885298</td>
#       <td>0.906107</td>
#       <td>0.889357</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.220000</td>
#       <td>0.300678</td>
#       <td>0.914447</td>
#       <td>0.903771</td>
#       <td>0.914447</td>
#       <td>0.906125</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.244200</td>
#       <td>0.277183</td>
#       <td>0.914716</td>
#       <td>0.908991</td>
#       <td>0.914716</td>
#       <td>0.911404</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.247600</td>
#       <td>0.271156</td>
#       <td>0.915792</td>
#       <td>0.906668</td>
#       <td>0.915792</td>
#       <td>0.908059</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.221700</td>
#       <td>0.259953</td>
#       <td>0.915523</td>
#       <td>0.904848</td>
#       <td>0.915523</td>
#       <td>0.907951</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.189000</td>
#       <td>0.274848</td>
#       <td>0.916330</td>
#       <td>0.915126</td>
#       <td>0.916330</td>
#       <td>0.915330</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.227100</td>
#       <td>0.275035</td>
#       <td>0.913909</td>
#       <td>0.909441</td>
#       <td>0.913909</td>
#       <td>0.911274</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.214200</td>
#       <td>0.273695</td>
#       <td>0.916599</td>
#       <td>0.903630</td>
#       <td>0.916599</td>
#       <td>0.905148</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.215800</td>
#       <td>0.254461</td>
#       <td>0.912026</td>
#       <td>0.901229</td>
#       <td>0.912026</td>
#       <td>0.904405</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.208900</td>
#       <td>0.271615</td>
#       <td>0.909874</td>
#       <td>0.901860</td>
#       <td>0.909874</td>
#       <td>0.904335</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.231800</td>
#       <td>0.263276</td>
#       <td>0.918752</td>
#       <td>0.914856</td>
#       <td>0.918752</td>
#       <td>0.916259</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.184000</td>
#       <td>0.260645</td>
#       <td>0.916330</td>
#       <td>0.907624</td>
#       <td>0.916330</td>
#       <td>0.910051</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.235800</td>
#       <td>0.256648</td>
#       <td>0.912833</td>
#       <td>0.907960</td>
#       <td>0.912833</td>
#       <td>0.910014</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.204800</td>
#       <td>0.260659</td>
#       <td>0.919290</td>
#       <td>0.909499</td>
#       <td>0.919290</td>
#       <td>0.909249</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.216900</td>
#       <td>0.264662</td>
#       <td>0.918483</td>
#       <td>0.907363</td>
#       <td>0.918483</td>
#       <td>0.907484</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.229700</td>
#       <td>0.257353</td>
#       <td>0.917945</td>
#       <td>0.907452</td>
#       <td>0.917945</td>
#       <td>0.909341</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.187700</td>
#       <td>0.258140</td>
#       <td>0.918483</td>
#       <td>0.910944</td>
#       <td>0.918483</td>
#       <td>0.913260</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.195500</td>
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-50
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-50\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-50\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-100
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-100\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-150
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-150\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-150\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-200
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-200\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-200\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-250
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-250\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-250\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-300
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-300\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-300\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-350
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-350\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-350\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-400
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-400\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-400\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-450
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-450\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-450\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-500
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-500\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-500\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-550
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-550\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-550\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-600
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-600\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-600\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-650
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-650\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-650\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-700
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-700\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-700\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-750
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-750\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-750\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-800
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-800\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-800\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-850
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-850\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-850\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# C:\Users\jesse\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-900
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-900\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-900\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-950
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-950\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-950\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1000
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1000\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1050
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1050\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1050\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1100
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1100\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1150
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1150\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1150\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1200
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1200\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1200\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1250
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1250\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1250\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1300
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1300\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1300\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1350
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1350\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1350\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1400
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1400\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1400\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1450
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1450\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1450\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1500
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1500\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1500\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1550
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1550\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1550\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1600
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1600\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1600\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1650
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1650\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1650\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1700
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1700\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1700\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# wandb: Network error resolved after 0:00:11.249517, resuming normal operation.
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1750
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1750\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1750\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1800
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1800\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1800\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1850
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1850\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1850\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1900
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1900\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1900\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-1950
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-1950\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-1950\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-2000
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-2000\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-2000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-2050
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-2050\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-2050\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-2100
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-2100\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-2100\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 3717
#   Batch size = 16
# Saving model checkpoint to D:\COS 802\Project\Bert Training\output\checkpoint-2150
# Configuration saved in D:\COS 802\Project\Bert Training\output\checkpoint-2150\config.json
# Model weights saved in D:\COS 802\Project\Bert Training\output\checkpoint-2150\pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from D:\COS 802\Project\Bert Training\output\checkpoint-1650 (score: 0.254461407661438).
# TrainOutput(global_step=2170, training_loss=0.2610917568206787, metrics={'train_runtime': 76274.859, 'train_samples_per_second': 0.455, 'train_steps_per_second': 0.028, 'total_flos': 1230273118677456.0, 'train_loss': 0.2610917568206787, 'epoch': 2.0})

# %%
# ----- 3. Predict -----#
# Load test data

X_test = list(df_test['text'])
y_test = list(df_test['label'])

X_test_tokenized = tokenizer(X_test, padding=True, truncation=True, max_length=512)

# %%
# Create torch dataset
test_dataset = Dataset(X_test_tokenized)

# %%
# Load trained model
model_path = "D:\COS 802\Project\Bert Training\output\checkpoint-1750"
model = BertForSequenceClassification.from_pretrained(model_path, num_labels=3)
# Out:
# loading configuration file D:\COS 802\Project\Bert Training\output\checkpoint-1750\config.json
# Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "torch_dtype": "float32",
#   "transformers_version": "4.10.3",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file D:\COS 802\Project\Bert Training\output\checkpoint-1750\pytorch_model.bin
# All model checkpoint weights were used when initializing BertForSequenceClassification.
#
# All the weights of BertForSequenceClassification were initialized from the model checkpoint at D:\COS 802\Project\Bert Training\output\checkpoint-1750.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForSequenceClassification for predictions without further training.

# %%
# Define test trainer
test_trainer = Trainer(model)
# Out:
# No `TrainingArguments` passed, using `output_dir=tmp_trainer`.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
# Make prediction
raw_pred, _, _ = test_trainer.predict(test_dataset)

# Preprocess raw predictions
y_pred = np.argmax(raw_pred, axis=1)
# Out:
# ***** Running Prediction *****
#   Num examples = 3718
#   Batch size = 8
#     <div>
#
#       <progress value='465' max='465' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [465/465 04:54]
#     </div>
# wandb: Network error resolved after 0:16:17.634312, resuming normal operation.

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[  90,  101,   22],
#        [  81, 2757,   67],
#        [  10,   38,  552]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.42      0.46       213
#            1       0.95      0.95      0.95      2905
#            2       0.86      0.92      0.89       600
#
#     accuracy                           0.91      3718
#    macro avg       0.77      0.76      0.77      3718
# weighted avg       0.91      0.91      0.91      3718
